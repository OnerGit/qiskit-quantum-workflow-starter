# %% [markdown]
# # Grover toy demo
# A local two-qubit educational Grover example.

# %%
from qiskit_quantum_workflow_starter import (
    create_grover_toy_circuit,
    run_local_simulation,
)

circuit = create_grover_toy_circuit("11")
counts = run_local_simulation(circuit)
circuit.draw("mpl"), counts
