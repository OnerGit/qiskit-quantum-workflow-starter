# %% [markdown]
# # Bell state demo
# A local, seeded Bell-state simulation.

# %%
from qiskit_quantum_workflow_starter import create_bell_circuit, run_local_simulation

circuit = create_bell_circuit()
counts = run_local_simulation(circuit)
circuit.draw("mpl"), counts
